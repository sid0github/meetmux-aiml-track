# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix


data = load_breast_cancer()
X_train,X_test,y_train,y_test = train_test_split(data.data, data.target, test_size=0.2, random_state=42)

scaler = StandardScaler()
X_scaled_train = scaler.fit_transform(X_train)
X_scaled_test = scaler.transform(X_test)

model = LogisticRegression()
model.fit(X_scaled_train, y_train)

y_pred = model.predict(X_scaled_test)
print(f"Model Accuracy: {accuracy_score(y_test, y_pred):.4f}") 

probs = model.predict_proba(X_scaled_test)
print(probs[:5])

import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred)

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Model Accuracy: 0.9737
# [[1.13590250e-01 8.86409750e-01]
#  [9.99990991e-01 9.00936206e-06]
#  [9.96920905e-01 3.07909541e-03]
#  [5.10134225e-04 9.99489866e-01]
#  [6.06389713e-05 9.99939361e-01]]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\_bunch.py:57, in Bunch.__getattr__(self, key)
#      56 try:
# ---> 57     return self[key]
#      58 except KeyError:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\_bunch.py:42, in Bunch.__getitem__(self, key)
#      38     warnings.warn(
#      39         self._deprecated_key_to_warnings[key],
#      40         FutureWarning,
#      41     )
# ---> 42 return super().__getitem__(key)
#
# KeyError: 'head'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(data.head())
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\_bunch.py:59, in Bunch.__getattr__(self, key)
#      57     return self[key]
#      58 except KeyError:
# ---> 59     raise AttributeError(key)
#
# AttributeError: head

# %% [markdown]
# False Negative is more dangerous because it means a sick person is incorrectly classified as healthy, leading to missed diagnosis and delayed treatment.
