# %%
import numpy as np
from sklearn.datasets import load_digits
from sklearn.model_selection import KFold, cross_val_score
from sklearn.ensemble import RandomForestClassifier

digits = load_digits()
X, y = digits.data, digits.target

model = RandomForestClassifier(n_estimators=50)
scores = cross_val_score(model,X,y,cv=5)

print(f"Scores for each fold: {scores}") 
print(f"Mean Accuracy: {np.mean(scores):.4f}") 
print(f"Standard Deviation (Stability): {np.std(scores):.4f}")

model.fit(X,y)
train_score = model.score(X,y)
print(f"Training Accuracy: {train_score:.4f}") 
print(f"Validation Accuracy: {np.mean(scores):.4f}")
# Out:
# Scores for each fold: [0.93611111 0.93055556 0.96935933 0.96657382 0.92200557]
# Mean Accuracy: 0.9449
# Standard Deviation (Stability): 0.0194
# Training Accuracy: 1.0000
# Validation Accuracy: 0.9449

# %%
kf = KFold(n_splits=10, shuffle=False)
scores_no_shuffle = cross_val_score(model, X, y, cv=kf)

print(f"Scores for each fold: {scores_no_shuffle}") 
print(f"Mean Accuracy: {np.mean(scores_no_shuffle):.4f}") 
print(f"Standard Deviation (Stability): {np.std(scores_no_shuffle):.4f}")
# Out:
# Scores for each fold: [0.9        0.98888889 0.95555556 0.93333333 0.95555556 0.97222222
#  0.96666667 0.97765363 0.93854749 0.93296089]
# Mean Accuracy: 0.9521
# Standard Deviation (Stability): 0.0250

# %%
kf = KFold(n_splits=10, shuffle=True, random_state = 42)
scores_no_shuffle = cross_val_score(model, X, y, cv=kf)

print(f"Scores for each fold: {scores_no_shuffle}") 
print(f"Mean Accuracy: {np.mean(scores_no_shuffle):.4f}") 
print(f"Standard Deviation (Stability): {np.std(scores_no_shuffle):.4f}")
# Out:
# Scores for each fold: [0.97777778 0.98333333 0.98333333 0.98888889 0.96666667 0.95
#  0.98333333 0.98324022 0.97206704 0.97206704]
# Mean Accuracy: 0.9761
# Standard Deviation (Stability): 0.0108

# %% [markdown]
# If we don't use shuffling in this K-fold, we see that fold1 is for bangalore, fold2 is also for bangalore,...., fold10 is delhi, so the model is clearly baised for users from bangalore and it fails for delhi. So, shuffling ensures that each fold represents the overall data distribution, preventing biased evaluation.
