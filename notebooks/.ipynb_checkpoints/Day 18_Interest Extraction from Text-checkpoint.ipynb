# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import string

nltk.download('punkt_tab') 
nltk.download('stopwords') 
nltk.download('wordnet') 

def clean_text(text):
    text= text.lower()
    text = text.translate(str.maketrans('', '', string.punctuation ))

    tokens = word_tokenize(text)

    lemmatizer =WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(w) for w in tokens]

    stop_words = set(stopwords.words('english')) 
    filtered_text = [w for w in tokens if not w in stop_words] 

    return ' '.join(filtered_text)

sample_bio = "I love Hiking in the mountains and Coding late at night!" 
print(f"Cleaned Bio: {clean_text(sample_bio)}")
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\magsi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\magsi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\magsi\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Cleaned Bio: love hiking mountain coding late night

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

bios = [
    "Expert in Python and Machine Learning for social good.",
    "Professional Chef who loves outdoor Hiking and mountains.",
    "Machine Learning enthusiast and mountain hiker."
]

vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(bios)

print("Vocabulary:", vectorizer.get_feature_names_out())
print("Vector Shape:", tfidf_matrix.toarray().shape)
# Out:
# Vocabulary: ['and' 'chef' 'enthusiast' 'expert' 'for' 'good' 'hiker' 'hiking' 'in'
#  'learning' 'loves' 'machine' 'mountain' 'mountains' 'outdoor'
#  'professional' 'python' 'social' 'who']
# Vector Shape: (3, 19)

# %%
pip install textblob
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/625.0 kB ? eta -:--:--
#    ---------------------------------------- 625.0/625.0 kB 2.9 MB/s  0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -umpy (c:\users\magsi\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\magsi\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\magsi\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\magsi\appdata\roaming\python\python310\site-packages)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from textblob import TextBlob

bios = [
    "I absolutely love hiking and outdoor adventures!",
    "Machine learning is quite interesting and useful.",
    "The weather was terrible and the event was boring.",
    "Python programming is the best skill I have learned.",
    "It was okay, nothing special about the experience."
]

for bio in bios:
    analysis = TextBlob(bio)
    print(f"Bio: {bio}")
    print(f"Polarity: {analysis.sentiment.polarity:.2f}")
    print(f"Subjectivity: {analysis.sentiment.subjectivity:.2f}")
    print("---")
# Out:
# Bio: I absolutely love hiking and outdoor adventures!
# Polarity: 0.62
# Subjectivity: 0.60
# ---
# Bio: Machine learning is quite interesting and useful.
# Polarity: 0.40
# Subjectivity: 0.25
# ---
# Bio: The weather was terrible and the event was boring.
# Polarity: -1.00
# Subjectivity: 1.00
# ---
# Bio: Python programming is the best skill I have learned.
# Polarity: 1.00
# Subjectivity: 0.30
# ---
# Bio: It was okay, nothing special about the experience.
# Polarity: 0.43
# Subjectivity: 0.54
# ---

# %% [markdown]
# MeetMux can implement an automated review monitoring
# system using Sentiment Analysis:
#
# 1. After each event, collect user reviews
# 2. Run TextBlob sentiment analysis on each review
# 3. Calculate average polarity per organizer
# 4. Flag organizers whose average polarity < 0.2
# 5. Trigger manual review or warning system
#
# Limitation:
# TextBlob analyzes words in isolation, missing context
# and sarcasm. A production system should use
# Transformer models like BERT for accurate
# context-aware sentiment detection.
