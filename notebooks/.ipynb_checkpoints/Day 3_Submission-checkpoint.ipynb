# %% [markdown]
# Vectorization is a process in AIML which is used to perform operations on entire arrays or datasets without using iterations, so  as it runs in lower level C or hardware level vectorisation is much faster and efficient compared to looping statements.
