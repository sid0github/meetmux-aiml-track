# %%
import pandas as pd

df = pd.read_csv('data.csv')

# %%
print(df.head())
# Out:
#       Name  Age  Score
# 0    Alice   21     80
# 1      Bob   22     75
# 2  Charlie   23     90

# %%
print(df.describe())
# Out:
#         Age      Score
# count   3.0   3.000000
# mean   22.0  81.666667
# std     1.0   7.637626
# min    21.0  75.000000
# 25%    21.5  77.500000
# 50%    22.0  80.000000
# 75%    22.5  85.000000
# max    23.0  90.000000

# %%
df.isnull().sum()
# Out:
# Name     0
# Age      0
# Score    0
# dtype: int64

# %%
df.drop(2)
# Out:
#     Name  Age  Score
# 0  Alice   21     80
# 1    Bob   22     75

# %%
df.loc[2] = ['sid', 23, 96]

# %% [markdown]
# print(df)

# %% [markdown]
# "Why is it better to fill a missing age with
# the mean rather than just putting 0?"
#
# Using mean to fill a missing age gives us a realistic, data supported filling value as it is closer to the other values.
